# %%
import dask.dataframe as dd
import simplejson as json

import dask
from dask.distributed import Client
import pandas as pd
from collections import Counter

# %%
INPUT_MASK = '../events/{event_count}-{nfiles}/year=*/month=*/day=*/hour=*/*/part*.parquet'
OUTPUT_MASK = '../aggs_dask/{event_count}-{nfiles}/*.json'

# %%
dask.set_options(get=dask.get)

# %%
client = Client()
# Out:
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-N61qOe', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-c3YaoK', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-EvdJuS', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-Juf6tU', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-19sTGk', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-oS4gom', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-7NBPoj', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-TPMJS5', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-dRrlIM', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-39x5rL', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-h95zp3', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-LyY37g', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-dhOyfm', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-HH_CXZ', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-r2irVR', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-zvaveS', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-FVtQg2', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-KemCWX', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-_0HIrD', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-QU274j', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-yRVHi4', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-fNu2m_', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-f2pw77', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-jeZCzL', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-zgvlpg', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-MTLbc0', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-81cxl3', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-d8ZIXN', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-CNX6ok', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-RoIIqz', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-VU0yL3', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-4Wmv6t', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-gFRcdz', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-YUe5lE', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-6sMgAw', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-Hwg8TF', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-K4Ulfe', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-ZZFCxe', purging
# distributed.diskutils - WARNING - Found stale lock file and directory '/Users/irina/src/talks/2018/daskvsspark/trials/dask-worker-space/worker-rWx8gF', purging
# --------------------
# counter_chunk
# 1
# --------------------
# --------------------
# counter_chunk
# 1
# counter_chunk
# 1
# --------------------
# counter_chunk
# 1
#                  customer                       url                  ts  \
# referrer
# http://bing.com/    a.com  http://a.com/articles/16 2017-09-17 08:00:00
#
#                           referrer  counts
# referrer
# http://bing.com/  http://bing.com/       1                     customer                       url                  ts  \
# referrer
# http://google.com/    a.com  http://a.com/articles/19 2017-09-17 06:00:00
#
#                               referrer  counts
# referrer
# http://google.com/  http://google.com/       1
#
#                  customer                       url                  ts  \
# referrer
# http://bing.com/    a.com  http://a.com/articles/17 2017-09-17 01:00:00
#
#                           referrer  counts
# referrer
# http://bing.com/  http://bing.com/       1                     customer                       url                  ts  \
# referrer
# http://google.com/    a.com  http://a.com/articles/20 2017-09-17 10:00:00
#
#                               referrer  counts
# referrer
# http://google.com/  http://google.com/       1
#
# referrer
# http://bing.com/    1
# Name: counts, dtype: int64referrer
# http://bing.com/    1
# Name: counts, dtype: int64
#
# referrer
# http://google.com/    1
# Name: counts, dtype: int64
# referrer
# http://google.com/    1
# Name: counts, dtype: int64
# --------------------
# counter_chunk
# 1
# --------------------
# --------------------
# counter_chunk
# counter_chunk
# 1
# 1
# --------------------
#                    customer                       url                  ts  \
# referrer
# http://bing.com/      a.com  http://a.com/articles/13 2017-09-17 12:00:00
# http://google.com/    a.com  http://a.com/articles/16 2017-09-17 12:00:00
#
#                               referrer  counts
# referrer
# http://bing.com/      http://bing.com/       2
# http://google.com/  http://google.com/       1  counter_chunk
#
# 1
#                    customer                      url                  ts  \
# referrer
# http://google.com/    a.com  http://a.com/articles/2 2017-09-17 19:00:00
#
#                               referrer  counts
# referrer
# http://google.com/  http://google.com/       1  referrer
# http://bing.com/      2
# http://google.com/    1
# Name: counts, dtype: int64
#                      customer                       url                  ts  \
# referrer
# http://facebook.com/    a.com  http://a.com/articles/17 2017-09-17 23:00:00
#
#                                   referrer  counts
# referrer
# http://facebook.com/  http://facebook.com/       1
# referrer
# http://google.com/    1
# Name: counts, dtype: int64
#                      customer                      url                  ts  \
# referrer
# http://facebook.com/    a.com  http://a.com/articles/3 2017-09-17 13:00:00
#
#                                   referrer  counts
# referrer
# http://facebook.com/  http://facebook.com/       1
#
# referrer
# http://facebook.com/    1
# Name: counts, dtype: int64referrer
# http://facebook.com/    1
# Name: counts, dtype: int64
#
# --------------------
# counter_agg
# ('current', nan)
# --------------------
# counter_agg
# ('current', nan)
# --------------------
# counter_agg
# ('current', nan)
# --------------------
# counter_agg
# ('current', nan)
# --------------------
# counter_agg
# ('current', nan)
# --------------------
# counter_agg
# ('current', nan)
# --------------------
# counter_agg
# ('current', nan)
# --------------------
# counter_agg
# ('current', nan)
# --------------------
# counter_agg
# ('current', nan)
# --------------------
# counter_agg
# ('current', nan)
# ('current', nan)
# ('current', nan)
# ('current', nan)
# ('current', nan)
# ('current', nan)
# ('current', nan)
# ('current', nan)
# ('current', nan)
# --------------------
# counter_chunk
# ('cols', Index([u'customer', u'url', u'ts', u'referrer', u'counts'], dtype='object'))
# --------------------
# counter_chunk
# --------------------
# [(u'http://bing.com/', 1)]
# ('cols', Index([u'customer', u'url', u'ts', u'referrer', u'counts'], dtype='object'))
# counter_chunk
# --------------------
# [(u'http://google.com/', 1)]
# ('cols', Index([u'customer', u'url', u'ts', u'referrer', u'counts'], dtype='object'))
# counter_chunk
# [(u'http://bing.com/', 1)]
# ('cols', Index([u'customer', u'url', u'ts', u'referrer', u'counts'], dtype='object'))
# --------------------
# [(u'http://google.com/', 1)]
# --------------------
# counter_chunk
# counter_chunk
# --------------------
# ('cols', Index([u'customer', u'url', u'ts', u'referrer', u'counts'], dtype='object'))
# counter_chunk
# ('cols', Index([u'customer', u'url', u'ts', u'referrer', u'counts'], dtype='object'))
# [(u'http://google.com/', 1)]
# [(u'http://facebook.com/', 1)]
# ('cols', Index([u'customer', u'url', u'ts', u'referrer', u'counts'], dtype='object'))
# [(u'http://google.com/', 1), (u'http://bing.com/', 2)]
# --------------------
# counter_chunk
# ('cols', Index([u'customer', u'url', u'ts', u'referrer', u'counts'], dtype='object'))
# [(u'http://facebook.com/', 1)]
# --------------------
# counter_agg
# ('current', (u'http://google.com/', 1))
# --------------------
# counter_agg
# ('current', (u'http://bing.com/', 1))
# --------------------
# counter_agg
# ('current', (u'http://bing.com/', 2))
# --------------------
# counter_agg
# ('current', (u'http://bing.com/', 1))
# --------------------
# counter_agg
# ('current', (u'http://facebook.com/', 1))
# --------------------
# counter_agg
# ('current', (u'http://google.com/', 1))
# --------------------
# counter_agg
# ('current', (u'http://google.com/', 1))
# --------------------
# counter_agg
# ('current', (u'http://google.com/', 1))
# --------------------
# counter_agg
# ('current', (u'http://facebook.com/', 1))
# --------------------
# counter_chunk
# --------------------
# --------------------
# [[(u'http://google.com/', 1)]]
# --------------------
# counter_chunk
# counter_chunk
# counter_chunk
# [[(u'http://google.com/', 1)]]
# [[(u'http://bing.com/', 1)]]
# [[(u'http://bing.com/', 1)]]
# --------------------
# --------------------
# --------------------
# counter_chunk
# counter_chunk
# counter_chunk
# [(u'http://google.com/', 1), (u'http://bing.com/', 2)]
# --------------------
# [[(u'http://facebook.com/', 1)]]
# [[(u'http://facebook.com/', 1)]]
# counter_chunk
# [[(u'http://google.com/', 1)]]
# ('chunk', (u'http://google.com/', 1))
# distributed.worker - WARNING -  Compute Failed
# Function:  execute_task
# args:      ((<built-in function apply>, <function _agg_finalize at 0x1169bcd70>, [(<function _concat at 0x116977aa0>, [                                                       count-session_id-6d6c48f47a6d276a1bd7fe2a2248b673  \
# customer url                      ts
# a.com    http://a.com/articles/17 2017-09-17 01:00:00                                                  1
#
#                                                        count_unique-session_id-c06b832f28152d5e12d83925f0c07826  \
# customer url                      ts
# a.com    http://a.com/articles/17 2017-09-17 01:00:00                                                  1
#
#                                                       counter-referrer-95243ccd29300c6455d4161a8174d006
# customer url                      ts
# a.com
# kwargs:    {}
# Exception: ValueError('dictionary update sequence element #0 has length 18; 2 is required',)
# --------------------
# counter_chunk
# --------------------
# [(u'http://bing.com/', 1)]
# --------------------
# --------------------
# counter_chunk
# counter_chunk
# counter_chunk
# [(u'http://google.com/', 1)]
# [(u'http://google.com/', 1)]
# [(u'http://bing.com/', 1)]
# --------------------
# --------------------
# counter_chunk
# --------------------
# counter_chunk
# counter_chunk
# [(u'http://google.com/', 1), (u'http://bing.com/', 2)]
# --------------------
# [(u'http://facebook.com/', 1)]
# [(u'http://facebook.com/', 1)]
# counter_chunk
# [(u'http://google.com/', 1)]
# --------------------
# counter_agg
# ('chunk', [(u'http://google.com/', 1)])
# ('total', Counter({u'http://google.com/': 1}))
# --------------------
# counter_agg
# ('chunk', [(u'http://bing.com/', 1)])
# ('total', Counter({u'http://bing.com/': 1}))
# --------------------
# counter_agg
# ('chunk', [(u'http://bing.com/', 2)])
# ('total', Counter({u'http://bing.com/': 2}))
# --------------------
# counter_agg
# ('chunk', [(u'http://bing.com/', 1)])
# ('total', Counter({u'http://bing.com/': 1}))
# --------------------
# counter_agg
# ('chunk', [(u'http://facebook.com/', 1)])
# ('total', Counter({u'http://facebook.com/': 1}))
# --------------------
# counter_agg
# ('chunk', [(u'http://google.com/', 1)])
# ('total', Counter({u'http://google.com/': 1}))
# --------------------
# counter_agg
# ('chunk', [(u'http://google.com/', 1)])
# ('total', Counter({u'http://google.com/': 1}))
# --------------------
# counter_agg
# ('chunk', [(u'http://google.com/', 1)])
# ('total', Counter({u'http://google.com/': 1}))
# --------------------
# counter_agg
# ('chunk', [(u'http://facebook.com/', 1)])
# ('total', Counter({u'http://facebook.com/': 1}))
# --------------------
# counter_chunk
# --------------------
# --------------------
# counter_chunk
# counter_chunk
# [(u'http://bing.com/', 1)]
# [(u'http://google.com/', 1)]
# [(u'http://bing.com/', 1)]
# --------------------
# --------------------
# --------------------
# counter_chunk
# counter_chunk
# counter_chunk
# [(u'http://google.com/', 1)]
# --------------------
# [(u'http://google.com/', 1)]
# [(u'http://facebook.com/', 1)]
# counter_chunk
# [(u'http://google.com/', 1), (u'http://bing.com/', 2)]
# --------------------
# counter_chunk
# [(u'http://facebook.com/', 1)]
# --------------------
# counter_agg
# ('chunk', [(u'http://google.com/', 1)])
# ('total', Counter({u'http://google.com/': 1}))
# --------------------
# counter_agg
# ('chunk', [(u'http://bing.com/', 1)])
# ('total', Counter({u'http://bing.com/': 1}))
# --------------------
# counter_agg
# ('chunk', [(u'http://bing.com/', 2)])
# ('total', Counter({u'http://bing.com/': 2}))
# --------------------
# counter_agg
# ('chunk', [(u'http://bing.com/', 1)])
# ('total', Counter({u'http://bing.com/': 1}))
# --------------------
# counter_agg
# ('chunk', [(u'http://facebook.com/', 1)])
# ('total', Counter({u'http://facebook.com/': 1}))
# --------------------
# counter_agg
# ('chunk', [(u'http://google.com/', 1)])
# ('total', Counter({u'http://google.com/': 1}))
# --------------------
# counter_agg
# ('chunk', [(u'http://google.com/', 1)])
# ('total', Counter({u'http://google.com/': 1}))
# --------------------
# counter_agg
# ('chunk', [(u'http://google.com/', 1)])
# ('total', Counter({u'http://google.com/': 1}))
# --------------------
# counter_agg
# ('chunk', [(u'http://facebook.com/', 1)])
# ('total', Counter({u'http://facebook.com/': 1}))

# %%
def read_data(read_path):
    """Reads the original Parquet data.
    :returns: DataFrame
    """
    df = dd.read_parquet(read_path).drop('hour', axis=1)
    return df

# %%
def counter_chunk(ser):
    sdf = ser.value_counts().to_frame('counts').reset_index()
    sdf = sdf.set_index(sdf.referrer)
    res = sdf.counts.to_dict().items()
    return res

# %%
def counter_agg(chunks):
    total = Counter()
    for chunk in chunks:
        if not isinstance(chunk[0], tuple):
            chunk = [chunk]
        current = Counter(dict(chunk))
        total = total + current
    return json.dumps(dict(total))

# %%
EVENT_COUNT = 10
NFILES = 24

# %%
read_path = INPUT_MASK.format(event_count=EVENT_COUNT, nfiles=NFILES)
write_path = OUTPUT_MASK.format(event_count=EVENT_COUNT, nfiles=NFILES)

# %%
df = read_data(read_path)

# %%
df.head(2, npartitions=8)
# Out:
#                         url            referrer session_id  \
# 0  http://a.com/articles/17    http://bing.com/        yyy
# 0  http://a.com/articles/19  http://google.com/        yyy
#
#                    ts customer
# 0 2017-09-17 01:03:00    a.com
# 0 2017-09-17 06:19:00    a.com

# %%
df['ts'] = df['ts'].dt.floor('1H')

# %%
gb = df.groupby(['customer', 'url', 'ts'])

# %%
counter = dd.Aggregation(
    'counter',
    lambda s: counter_chunk(s),
    lambda s: s.apply(counter_agg),
)

# %%
count_unique = dd.Aggregation(
    'count_unique',
    lambda s: s.nunique(),
    lambda s: s.nunique()
)

# %%
ag = gb.agg({
    'session_id': [count_unique, 'count'],
    'referrer': counter}
)
# Out:
# --------------------
# counter_chunk
# [('foo', 2)]
# --------------------
# counter_agg
# ('chunk', [('foo', 2)])
# ('total', Counter({'foo': 2}))

# %%
ag.head(8)
# Out:
#                                                                           referrer  \
#                                                                            counter
# customer url                      ts
# a.com    http://a.com/articles/13 2017-09-17 12:00:00    {"http://google.com/": 1}
#          http://a.com/articles/16 2017-09-17 08:00:00      {"http://bing.com/": 1}
#                                   2017-09-17 12:00:00      {"http://bing.com/": 2}
#          http://a.com/articles/17 2017-09-17 01:00:00      {"http://bing.com/": 1}
#                                   2017-09-17 23:00:00  {"http://facebook.com/": 1}
#          http://a.com/articles/19 2017-09-17 06:00:00    {"http://google.com/": 1}
#          http://a.com/articles/2  2017-09-17 19:00:00    {"http://google.com/": 1}
#          http://a.com/articles/20 2017-09-17 10:00:00    {"http://google.com/": 1}
#
#                                                         session_id
#                                                       count_unique count
# customer url                      ts
# a.com    http://a.com/articles/13 2017-09-17 12:00:00            1     2
#          http://a.com/articles/16 2017-09-17 08:00:00            1     1
#                                   2017-09-17 12:00:00            1     1
#          http://a.com/articles/17 2017-09-17 01:00:00            1     1
#                                   2017-09-17 23:00:00            1     1
#          http://a.com/articles/19 2017-09-17 06:00:00            1     1
#          http://a.com/articles/2  2017-09-17 19:00:00            1     1
#          http://a.com/articles/20 2017-09-17 10:00:00            1     1
